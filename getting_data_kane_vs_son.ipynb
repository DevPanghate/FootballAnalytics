# %%
#imports
from statsbombpy import sb
import mplsoccer

import pandas as pd
import numpy as np
import math

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from copy import deepcopy
from ast import literal_eval

# %%
#df settings
pd.set_option("display.max_rows", 150)
pd.set_option("display.max_columns", 50)

# %%
data = pd.read_csv('only_played.csv')
data2 = pd.read_csv('latest.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'season_x', 'name', 'position', 'team_x',
#        'assists', 'bonus', 'bps', 'clean_sheets', 'creativity', 'element',
#        'fixture', 'goals_conceded', 'goals_scored', 'ict_index', 'influence',
#        'kickoff_time', 'minutes', 'opponent_team', 'opp_team_name',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'round', 'saves', 'selected', 'team_a_score', 'team_h_score', 'threat',
#        'total_points', 'transfers_balance', 'transfers_in', 'transfers_out',
#        'value', 'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
data.drop(columns=['Unnamed: 0','Unnamed: 0.1'],inplace=True)

# %%
kane = data[data['name']=='Harry Kane']
kane2 = data2[data2['name']=='Harry Kane']
son = data[data['name']=='Heung-Min Son']
son2 = data2[data2['name']=='Son Heung-min']

# %%
mid_fwd = data[(data['position']=='MID') | (data['position']=='FWD')]
mid_fwd
# Out:
#       season_x                name position       team_x  assists  bonus  bps  \
# 1      2016-17        Aaron Lennon      MID      Burnley        0      0    6
# 2      2016-17        Aaron Ramsey      MID      Arsenal        0      0    5
# 3      2016-17  Abdoulaye Doucouré      MID      Everton        0      0    0
# 4      2016-17        Adam Forshaw      MID        Leeds        0      0    3
# 5      2016-17        Adam Lallana      MID     Brighton        1      2   33
# ...        ...                 ...      ...          ...      ...    ...  ...
# 98393  2021-22        Jack Grieves      FWD      Watford        0      0    0
# 98395  2021-22        N'Golo Kanté      MID      Chelsea        0      0   12
# 98396  2021-22         Josh Martin      MID      Norwich        0      0    0
# 98397  2021-22       Wilfred Ndidi      MID    Leicester        0      0    0
# 98399  2021-22      Nathan Redmond      MID  Southampton        0      0    5
#
# ...

# %%
kane
# Out:
#       season_x        name position team_x  assists  bonus  bps  clean_sheets  \
# 66     2016-17  Harry Kane      FWD  Spurs        0      0    5             0
# 259    2016-17  Harry Kane      FWD  Spurs        0      0    0             0
# 465    2016-17  Harry Kane      FWD  Spurs        0      2   26             0
# 671    2016-17  Harry Kane      FWD  Spurs        0      3   57             0
# 878    2016-17  Harry Kane      FWD  Spurs        0      0    6             0
# ...        ...         ...      ...    ...      ...    ...  ...           ...
# 95728  2021-22  Harry Kane      FWD  Spurs        0      0    3             1
# 96459  2021-22  Harry Kane      FWD  Spurs        0      0   22             0
# 97457  2021-22  Harry Kane      FWD  Spurs        0      0   10             0
# 97458  2021-22  Harry Kane      FWD  Spurs        0      3   57             1
# 98272  2021-22  Harry Kane      FWD  Spurs        1      1   42             1
#
# ...

# %%
kane2
# Out:
#             name position   team   xP  assists  bonus  bps  clean_sheets  \
# 442   Harry Kane      FWD  Spurs  4.4        0      0    4             0
# 1020  Harry Kane      FWD  Spurs  5.0        0      2   32             0
# 1609  Harry Kane      FWD  Spurs  5.8        0      1   30             1
# 2208  Harry Kane      FWD  Spurs  7.5        0      3   45             1
# 2814  Harry Kane      FWD  Spurs  6.7        1      0   14             0
# 3435  Harry Kane      FWD  Spurs  8.6        0      3   37             1
# 3926  Harry Kane      FWD  Spurs  9.0        1      1   38             0
# 4019  Harry Kane      FWD  Spurs  0.0        0      0   26             0
# 4020  Harry Kane      FWD  Spurs  0.0        0      2   28             1
#
#       creativity  element  fixture  goals_conceded  goals_scored  ict_index  \
# 442         22.2      427        8               1             0        7.1
# 1020        33.1      427       15               2             1       11.7
# ...

# %%
son2
# Out:
#                name position   team   xP  assists  bonus  bps  clean_sheets  \
# 210   Son Heung-min      MID  Spurs  4.2        1      0   23             0
# 786   Son Heung-min      MID  Spurs  3.5        0      0    3             0
# 1371  Son Heung-min      MID  Spurs  3.8        0      0   -2             1
# 1967  Son Heung-min      MID  Spurs  4.2        0      0    2             1
# 2569  Son Heung-min      MID  Spurs  3.5        0      0    2             0
# 3181  Son Heung-min      MID  Spurs  3.4        0      0   10             0
# 3735  Son Heung-min      MID  Spurs  7.0        0      3   55             0
# 4021  Son Heung-min      MID  Spurs  0.0        0      0    9             0
# 4022  Son Heung-min      NaN  Spurs  0.0        1      0   22             1
#
#       creativity  element  fixture  goals_conceded  goals_scored  ict_index  \
# 210         52.5      428        8               1             0       14.5
# ...

# %%
cols = kane.columns.values

# %%
kane2.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
#        'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
#        'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'red_cards', 'round', 'saves', 'selected', 'team_a_score',
#        'team_h_score', 'threat', 'total_points', 'transfers_balance',
#        'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards',
#        'GW'],
#       dtype='object')

# %%
kane2.drop(columns=['xP'],inplace=True)
kane2.rename(columns={'team':'team_x'},inplace=True)
kane2['season_x'] = '2022-23'
son2.drop(columns=['xP'],inplace=True)
son2.rename(columns={'team':'team_x'},inplace=True)
son2['season_x'] = '2022-23'
son2['name'] = 'Heung-Min Son'
# Out:
# C:\Users\Dev Panghate\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\Dev Panghate\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# <ipython-input-13-8f294fef9458>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
teams = pd.read_csv('teams_data.csv')
teams
# Out:
#     code  draw  form  id  loss            name  played  points  position  \
# 0      3     0   NaN   1     0         Arsenal       0       0         0
# 1      7     0   NaN   2     0     Aston Villa       0       0         0
# 2     91     0   NaN   3     0     Bournemouth       0       0         0
# 3     94     0   NaN   4     0       Brentford       0       0         0
# 4     36     0   NaN   5     0        Brighton       0       0         0
# 5      8     0   NaN   6     0         Chelsea       0       0         0
# 6     31     0   NaN   7     0  Crystal Palace       0       0         0
# 7     11     0   NaN   8     0         Everton       0       0         0
# 8     54     0   NaN   9     0          Fulham       0       0         0
# 9     13     0   NaN  10     0       Leicester       0       0         0
# 10     2     0   NaN  11     0           Leeds       0       0         0
# 11    14     0   NaN  12     0       Liverpool       0       0         0
# ...

# %%
id_dict = {}
for index,row in teams.iterrows():
    id_dict[row['id']] = row['name']
id_dict
# Out:
# {1: 'Arsenal',
#  2: 'Aston Villa',
#  3: 'Bournemouth',
#  4: 'Brentford',
#  5: 'Brighton',
#  6: 'Chelsea',
#  7: 'Crystal Palace',
#  8: 'Everton',
#  9: 'Fulham',
#  10: 'Leicester',
#  11: 'Leeds',
#  12: 'Liverpool',
#  13: 'Man City',
#  14: 'Man Utd',
#  15: 'Newcastle',
#  16: "Nott'm Forest",
#  17: 'Southampton',
#  18: 'Spurs',
#  19: 'West Ham',
#  20: 'Wolves'}

# %%
l1=[]
l2=[]
for index,row in kane2.iterrows():
    #print(row['opp_team_name'],id_dict[row['opponent_team']])
    l1.append(id_dict[row['opponent_team']])
kane2['opp_team_name'] = l1    
for index,row in son2.iterrows():
    #print(row['opp_team_name'],id_dict[row['opponent_team']])
    l2.append(id_dict[row['opponent_team']])
son2['opp_team_name'] = l2
# Out:
# <ipython-input-16-3b3d0f56c9f5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kane2['opp_team_name'] = l1
# <ipython-input-16-3b3d0f56c9f5>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   son2['opp_team_name'] = l2

# %%
kane2 = kane2[cols]
son2 = son2[cols]

# %%
kane = pd.concat([kane, kane2])
son = pd.concat([son,son2])

# %%
kane
# Out:
#      season_x        name position team_x  assists  bonus  bps  clean_sheets  \
# 66    2016-17  Harry Kane      FWD  Spurs        0      0    5             0
# 259   2016-17  Harry Kane      FWD  Spurs        0      0    0             0
# 465   2016-17  Harry Kane      FWD  Spurs        0      2   26             0
# 671   2016-17  Harry Kane      FWD  Spurs        0      3   57             0
# 878   2016-17  Harry Kane      FWD  Spurs        0      0    6             0
# ...       ...         ...      ...    ...      ...    ...  ...           ...
# 2814  2022-23  Harry Kane      FWD  Spurs        1      0   14             0
# 3435  2022-23  Harry Kane      FWD  Spurs        0      3   37             1
# 3926  2022-23  Harry Kane      FWD  Spurs        1      1   38             0
# 4019  2022-23  Harry Kane      FWD  Spurs        0      0   26             0
# 4020  2022-23  Harry Kane      FWD  Spurs        0      2   28             1
#
# ...

# %%
kane.to_csv('kane_data.csv')
son.to_csv('son_data.csv')
